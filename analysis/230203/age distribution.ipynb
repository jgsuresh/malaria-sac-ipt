# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %%
df = pd.read_csv("../../run_sims/Assets/primary_school_attendance_by_age.csv")

# %%
plt.figure(dpi=300)
plt.plot(df["age"], df["relative_attendance"]*0.85, marker='o')
plt.xlabel("Age")
plt.ylabel("Percentage attending primary school")
plt.xticks(range(6,19))
plt.ylim([0,1])
plt.savefig("age_distribution.png")
plt.savefig("age_distribution.pdf")
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
df
# Out:
#     age  relative_attendance
# 0     6                1.000
# 1     7                1.000
# 2     8                1.000
# 3     9                1.000
# 4    10                1.000
# 5    11                1.000
# 6    12                1.000
# 7    13                0.775
# 8    14                0.550
# 9    15                0.325
# 10   16                0.100
# 11   17                0.075
# 12   18                0.050

# %%
(1+0.775+0.550)*0.85/3
# Out:
# 0.6587500000000001

# %%
(0.325+0.1+0.075+0.05)*0.85/4
# Out:
# 0.116875
