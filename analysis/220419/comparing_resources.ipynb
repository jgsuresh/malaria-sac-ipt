# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %%
df1 = pd.read_csv("sim_data_7dfbe25b-29c0-ec11-a9f6-9440c9be2c51.csv")
df2 = pd.read_csv("sim_data_5d3e97d2-2bc0-ec11-a9f6-9440c9be2c51.csv")
df = pd.concat([df1,df2])

# %%
foo = df[np.in1d(df["scenario_number"], [13,22,30])].groupby(["archetype","baseline_eir","scenario_number"]).agg("mean").reset_index()

# %%
foo
# Out:
#    archetype  baseline_eir  scenario_number  iptsc_rdts_used  \
# 0    Central             1               13              0.0
# 1    Central             1               22              0.0
# 2    Central             1               30              0.0
# 3    Central             3               13              0.0
# 4    Central             3               22              0.0
# 5    Central             3               30              0.0
# 6    Central            10               13              0.0
# 7    Central            10               22              0.0
# 8    Central            10               30              0.0
# 9    Central            30               13              0.0
# 10   Central            30               22              0.0
# 11   Central            30               30              0.0
# 12   Central           100               13              0.0
# 13   Central           100               22              0.0
# ...

# %%
bar = foo[foo["scenario_number"]==13]
bar[["archetype", "baseline_eir", "clinical_incidence0_5","clinical_incidence6_15"]]
# Out:
#    archetype  baseline_eir  clinical_incidence0_5  clinical_incidence6_15
# 0    Central             1               1.337848                1.398473
# 3    Central             3               1.607833                1.521595
# 6    Central            10               2.640212                1.532129
# 9    Central            30               3.988325                1.336550
# 12   Central           100               5.411335                1.020438
# 15     Sahel             1               0.384840                0.744986
# 18     Sahel             3               0.677625                1.024186
# 21     Sahel            10               1.190600                1.211700
# 24     Sahel            30               1.845433                1.177232
# 27     Sahel           100               2.680529                1.147825
# 30  Southern             1               0.346732                0.433699
# 33  Southern             3               0.742214                0.799917
# ...

# %%
base = foo[foo["scenario_number"]==30]
base[["archetype", "baseline_eir", "clinical_incidence0_5","clinical_incidence6_15"]]
# Out:
#    archetype  baseline_eir  clinical_incidence0_5  clinical_incidence6_15
# 2    Central             1               1.882462                2.548678
# 5    Central             3               2.209082                2.705480
# 8    Central            10               3.490677                2.816143
# 11   Central            30               4.619870                2.591003
# 14   Central           100               5.813160                2.186162
# 17     Sahel             1               0.535099                1.321974
# 20     Sahel             3               0.881620                1.764436
# 23     Sahel            10               1.482808                2.137062
# 26     Sahel            30               2.194036                2.290077
# 29     Sahel           100               3.026967                2.365748
# 32  Southern             1               0.480711                0.785269
# 35  Southern             3               1.032623                1.370883
# ...

# %%
(2.186162-1.020438)/2.186162
# Out:
# 0.5332285530532505
