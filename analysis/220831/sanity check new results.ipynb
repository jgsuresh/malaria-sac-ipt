# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %%
df_new = pd.read_csv("sim_data_full.csv")
df_old = pd.read_csv("../220708/sim_data_summary_220708.csv")

# %%
df_new[df_new["scenario_number"]==30]
# Out:
#     archetype  baseline_eir  scenario_number  iptsc_rdts_used  \
# 150   Central             1               30              0.0
# 151   Central             3               30              0.0
# 152   Central            10               30              0.0
# 153   Central            30               30              0.0
# 154   Central           100               30              0.0
# 430     Sahel             1               30              0.0
# 431     Sahel             3               30              0.0
# 432     Sahel            10               30              0.0
# 433     Sahel            30               30              0.0
# 434     Sahel           100               30              0.0
# 750  Southern             1               30              0.0
# 751  Southern             3               30              0.0
# 752  Southern            10               30              0.0
# 753  Southern            30               30              0.0
# ...

# %%
df_old[df_old["scenario_number"]==30]
# Out:
#     archetype  baseline_eir  scenario_number  iptsc_rdts_used  \
# 150   Central             1               30              0.0
# 151   Central             3               30              0.0
# 152   Central            10               30              0.0
# 153   Central            30               30              0.0
# 154   Central           100               30              0.0
# 430     Sahel             1               30              0.0
# 431     Sahel             3               30              0.0
# 432     Sahel            10               30              0.0
# 433     Sahel            30               30              0.0
# 434     Sahel           100               30              0.0
# 750  Southern             1               30              0.0
# 751  Southern             3               30              0.0
# 752  Southern            10               30              0.0
# 753  Southern            30               30              0.0
# ...
