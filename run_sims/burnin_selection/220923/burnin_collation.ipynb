# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %%
df_central = pd.read_csv("central/burnin_outpaths.csv")
df_southern = pd.read_csv("southern/burnin_outpaths.csv")
df_sahel = pd.read_csv("sahel/burnin_outpaths.csv")

# %%
pfpr_selected = [0.01,0.05,0.1,0.2,0.3,0.4]
aeir_selected = [1,3,10,30,100]

# %%
df_central.columns
# Out:
# Index(['habitat_scale', 'sim_id', 'outpath', 'aeir_SMOOTHED',
#        'annual_cases_per_1000_SMOOTHED', 'annual_rdt_prev_SMOOTHED',
#        'pfemp_frac_SMOOTHED', 'annual_reported_cases_per_1000_SMOOTHED',
#        'pfpr_2-10_SMOOTHED'],
#       dtype='object')

# %%
def select_closest(df):
    save_rows = []
    for p in pfpr_selected:
        i = np.argmin(np.abs(df["pfpr_2-10_SMOOTHED"]-p))
        s = df.iloc[i]
        s["burnin_approx_pfpr_2-10"] = p
        save_rows.append(s)
    
    for e in aeir_selected:
        i = np.argmin(np.abs(df["aeir_SMOOTHED"]-e))
        s = df.iloc[i]
        s["burnin_approx_aeir"] = e
        save_rows.append(s)
        
    return pd.DataFrame(save_rows)

# %%
df_list = []

dc = select_closest(df_sahel)
dc["archetype"] = "Sahel"
df_list.append(dc.copy())

dc = select_closest(df_central)
dc["archetype"] = "Central"
df_list.append(dc.copy())

dc = select_closest(df_southern)
dc["archetype"] = "Southern"
df_list.append(dc.copy())


df_save = pd.concat(df_list).reset_index(drop=True)
# Out:
# C:\Users\joshsu\AppData\Local\Temp/ipykernel_36252/2725800862.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s["burnin_approx_pfpr_2-10"] = p
# c:\users\joshsu\venv\dev\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\joshsu\AppData\Local\Temp/ipykernel_36252/2725800862.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s["burnin_approx_aeir"] = e

# %%
df_save
# Out:
#     habitat_scale                                sim_id  \
# 0             8.1  7c19b206-9f3a-ed11-a9fc-b88303911bc1
# 1             8.5  4b12aa0c-9f3a-ed11-a9fc-b88303911bc1
# 2             8.8  93725213-9f3a-ed11-a9fc-b88303911bc1
# 3             9.4  5d6c4a19-9f3a-ed11-a9fc-b88303911bc1
# 4             9.9  c5d91021-9f3a-ed11-a9fc-b88303911bc1
# 5            10.4  0250f62d-9f3a-ed11-a9fc-b88303911bc1
# 6             8.4  b419b206-9f3a-ed11-a9fc-b88303911bc1
# 7             8.7  dd13aa0c-9f3a-ed11-a9fc-b88303911bc1
# 8             9.1  3f6c4a19-9f3a-ed11-a9fc-b88303911bc1
# 9             9.6  b6d71021-9f3a-ed11-a9fc-b88303911bc1
# 10           10.1  60d00827-9f3a-ed11-a9fc-b88303911bc1
# 11            7.1  332e2435-9f3a-ed11-a9fc-b88303911bc1
# 12            7.3  702e2435-9f3a-ed11-a9fc-b88303911bc1
# 13            7.5  68271c3b-9f3a-ed11-a9fc-b88303911bc1
# 14            7.8  37201441-9f3a-ed11-a9fc-b88303911bc1
# 15            8.1  012b1f47-9f3a-ed11-a9fc-b88303911bc1
# 16            8.4  212b1f47-9f3a-ed11-a9fc-b88303911bc1
# 17            7.3  702e2435-9f3a-ed11-a9fc-b88303911bc1
# 18            7.6  1d281c3b-9f3a-ed11-a9fc-b88303911bc1
# 19            8.0  59201441-9f3a-ed11-a9fc-b88303911bc1
# 20            8.5  2a2b1f47-9f3a-ed11-a9fc-b88303911bc1
# 21            9.0  a8128a4f-9f3a-ed11-a9fc-b88303911bc1
# 22            7.6  382cb97b-9f3a-ed11-a9fc-b88303911bc1
# 23            8.0  7d5ad682-9f3a-ed11-a9fc-b88303911bc1
# 24            8.2  5a5cd682-9f3a-ed11-a9fc-b88303911bc1
# 25            8.7  cebfdb8e-9f3a-ed11-a9fc-b88303911bc1
# 26            9.2  6bfdda94-9f3a-ed11-a9fc-b88303911bc1
# 27            9.7  3b14d2a0-9f3a-ed11-a9fc-b88303911bc1
# 28            7.8  575ad682-9f3a-ed11-a9fc-b88303911bc1
# 29            8.1  4f5cd682-9f3a-ed11-a9fc-b88303911bc1
# 30            8.5  16dfd788-9f3a-ed11-a9fc-b88303911bc1
# 31            9.0  d9fcda94-9f3a-ed11-a9fc-b88303911bc1
# 32            9.5  585bd59a-9f3a-ed11-a9fc-b88303911bc1
#
#                                               outpath  aeir_SMOOTHED  \
# 0   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       0.172094
# 1   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       1.414376
# 2   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       3.781448
# 3   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      19.163682
# 4   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      60.578777
# 5   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...     185.720688
# 6   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       0.903020
# 7   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       2.825603
# 8   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       9.218256
# 9   //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      30.748541
# 10  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      95.654647
# 11  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       0.124486
# 12  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       0.781040
# 13  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       2.145537
# 14  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       5.464150
# 15  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      11.758850
# 16  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      23.845991
# 17  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       0.781040
# 18  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       3.025207
# 19  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       9.137711
# 20  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      29.827351
# 21  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      94.320382
# 22  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       0.410729
# 23  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       2.041916
# 24  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       4.232440
# 25  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      16.342137
# 26  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      50.395663
# 27  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...     150.626724
# 28  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       1.053231
# 29  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       2.962121
# 30  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...       9.570492
# 31  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      32.204615
# 32  //mnt/idm2/home/jsuresh/output/IPTsc burnins_d...      96.104126
#
#     annual_cases_per_1000_SMOOTHED  annual_rdt_prev_SMOOTHED  \
# 0                        48.357249                  0.011216
# 1                       208.578506                  0.055483
# 2                       343.239019                  0.097195
# 3                       575.754699                  0.177131
# 4                       748.980815                  0.245742
# 5                       890.020644                  0.302055
# 6                       154.865538                  0.039958
# 7                       305.197713                  0.084978
# 8                       461.088293                  0.137396
# 9                       636.282148                  0.199754
# 10                      812.617257                  0.270779
# 11                       52.666163                  0.011882
# 12                      234.193727                  0.054775
# 13                      464.946891                  0.113539
# 14                      715.820952                  0.184865
# 15                      914.259973                  0.245380
# 16                     1072.482912                  0.297534
# 17                      234.193727                  0.054775
# 18                      558.182705                  0.139003
# 19                      848.933111                  0.225253
# 20                     1115.042274                  0.311687
# 21                     1303.309392                  0.372839
# 22                      134.789491                  0.030596
# 23                      341.585839                  0.081898
# 24                      482.270264                  0.118587
# 25                      753.947154                  0.195292
# 26                      969.756283                  0.260834
# 27                     1159.114707                  0.322191
# 28                      236.952924                  0.055067
# 29                      412.494382                  0.100095
# 30                      639.839838                  0.162476
# 31                      885.374989                  0.234551
# 32                     1087.581395                  0.298482
#
#     pfemp_frac_SMOOTHED  annual_reported_cases_per_1000_SMOOTHED  \
# 0              0.284088                                17.199592
# 1              0.395077                                75.852884
# 2              0.468501                               127.527719
# 3              0.592864                               231.965999
# 4              0.671840                               328.425699
# 5              0.728266                               422.229791
# 6              0.370018                                56.632585
# 7              0.444060                               111.871892
# 8              0.535487                               177.843329
# 9              0.626002                               266.027113
# 10             0.696489                               368.277898
# 11             0.322260                                18.410432
# 12             0.390481                                86.086522
# 13             0.457533                               179.195742
# 14             0.542667                               296.781310
# 15             0.613530                               406.143506
# 16             0.670406                               504.712516
# 17             0.390481                                86.086522
# 18             0.487514                               220.496202
# 19             0.591058                               368.379925
# 20             0.686849                               535.168200
# 21             0.748505                               672.206348
# 22             0.241337                                48.338018
# 23             0.359521                               132.640424
# 24             0.417656                               191.043971
# 25             0.535892                               320.851722
# 26             0.628176                               439.527855
# 27             0.701484                               562.525852
# 28             0.299657                                88.768146
# 29             0.388760                               161.364677
# 30             0.490778                               265.764941
# 31             0.594423                               391.240778
# 32             0.674440                               515.032502
#
#     pfpr_2-10_SMOOTHED  burnin_approx_pfpr_2-10  burnin_approx_aeir archetype
# 0             0.011294                     0.01                 NaN     Sahel
# 1             0.051133                     0.05                 NaN     Sahel
# 2             0.092730                     0.10                 NaN     Sahel
# 3             0.195881                     0.20                 NaN     Sahel
# 4             0.300492                     0.30                 NaN     Sahel
# 5             0.392058                     0.40                 NaN     Sahel
# 6             0.037212                      NaN                 1.0     Sahel
# 7             0.079965                      NaN                 3.0     Sahel
# 8             0.143033                      NaN                10.0     Sahel
# 9             0.234319                      NaN                30.0     Sahel
# 10            0.338501                      NaN               100.0     Sahel
# 11            0.009172                     0.01                 NaN   Central
# 12            0.048804                     0.05                 NaN   Central
# 13            0.107734                     0.10                 NaN   Central
# 14            0.198609                     0.20                 NaN   Central
# 15            0.294954                     0.30                 NaN   Central
# 16            0.387509                     0.40                 NaN   Central
# 17            0.048804                      NaN                 1.0   Central
# 18            0.138192                      NaN                 3.0   Central
# 19            0.260676                      NaN                10.0   Central
# 20            0.413893                      NaN                30.0   Central
# 21            0.527219                      NaN               100.0   Central
# 22            0.013084                     0.01                 NaN  Southern
# 23            0.055465                     0.05                 NaN  Southern
# 24            0.094163                     0.10                 NaN  Southern
# 25            0.189577                     0.20                 NaN  Southern
# 26            0.299351                     0.30                 NaN  Southern
# 27            0.410628                     0.40                 NaN  Southern
# 28            0.031780                      NaN                 1.0  Southern
# 29            0.074242                      NaN                 3.0  Southern
# 30            0.143305                      NaN                10.0  Southern
# 31            0.253993                      NaN                30.0  Southern
# 32            0.366803                      NaN               100.0  Southern

# %%
df_save.to_csv("burnins.csv", index=False)
