# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %%
from jsuresh_helpers.burnins.burnins import survey_burnin_sweep
# Out:
# INI File Used: C:\Users\joshsu\Code\malaria-sac-ipt\idmtools.ini

# %%
df_burnin_all = pd.read_csv("burnin_endpoint_0dd75eef-9e3a-ed11-a9fc-b88303911bc1.csv")

# %%
df_sahel = df_burnin_all[df_burnin_all["archetype"]=="Sahel"].reset_index(drop=True)
survey_burnin_sweep(df_burnin=df_sahel, experiment_id="0dd75eef-9e3a-ed11-a9fc-b88303911bc1", tags_to_group_by="habitat_scale", lowess_frac=0.1)
# Out:
# [SLURM]
# {
#    "type": "COMPS",
#    "endpoint": "https://comps.idmod.org",
#    "environment": "Calculon",
#    "priority": "Highest",
#    "simulation_root": "$COMPS_PATH(USER)\\output",
#    "num_retries": "0",
#    "node_group": "idm_48cores",
#    "num_cores": "1",
#    "exclusive": "False"
# }

# %%
df_southern = df_burnin_all[df_burnin_all["archetype"]=="Southern"].reset_index(drop=True)
survey_burnin_sweep(df_burnin=df_southern, experiment_id="0dd75eef-9e3a-ed11-a9fc-b88303911bc1", tags_to_group_by="habitat_scale", lowess_frac=0.1)
# Out:
# [SLURM]
# {
#    "type": "COMPS",
#    "endpoint": "https://comps.idmod.org",
#    "environment": "Calculon",
#    "priority": "Highest",
#    "simulation_root": "$COMPS_PATH(USER)\\output",
#    "num_retries": "0",
#    "node_group": "idm_48cores",
#    "num_cores": "1",
#    "exclusive": "False"
# }

# %%
df_central = df_burnin_all[df_burnin_all["archetype"]=="Central"].reset_index(drop=True)
survey_burnin_sweep(df_burnin=df_central, experiment_id="0dd75eef-9e3a-ed11-a9fc-b88303911bc1", tags_to_group_by="habitat_scale", lowess_frac=0.1)
# Out:
# [SLURM]
# {
#    "type": "COMPS",
#    "endpoint": "https://comps.idmod.org",
#    "environment": "Calculon",
#    "priority": "Highest",
#    "simulation_root": "$COMPS_PATH(USER)\\output",
#    "num_retries": "0",
#    "node_group": "idm_48cores",
#    "num_cores": "1",
#    "exclusive": "False"
# }
